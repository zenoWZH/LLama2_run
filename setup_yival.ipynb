# %%
#! poetry run python -m ipykernel install --user --name forpoetry
#! poetry python -V
#! poetry run pip -V

# %%
! pip install accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.41.1 transformers==4.33.0 trl==0.4.7 scipy tensorboard tensorboardX tqdm ipywidgets bitsandbytes-cuda117
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
! pip install --no-cache-dir transformers sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
